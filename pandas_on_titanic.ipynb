# %% [markdown]
# # pandas on Titanic Dataset

# %%
import pandas as pd

# %%
from djmodel import get_model_repr

# %%
titanic_data = pd.read_csv('titanic.csv')

# %%
df =titanic_data

# %%
df.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
df.shape
# Out:
# (891, 12)

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB

# %%
df['Survived'][:5]
# Out:
# 0    0
# 1    1
# 2    1
# 3    1
# 4    0
# Name: Survived, dtype: int64

# %%
df[['Name','Age','Ticket']][:5]
# Out:
#                                                 Name   Age            Ticket
# 0                            Braund, Mr. Owen Harris  22.0         A/5 21171
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0          PC 17599
# 2                             Heikkinen, Miss. Laina  26.0  STON/O2. 3101282
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0            113803
# 4                           Allen, Mr. William Henry  35.0            373450

# %%
df['Pclass'].value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
df['Survived'].value_counts(normalize=True) * 100
# Out:
# 0    61.616162
# 1    38.383838
# Name: Survived, dtype: float64

# %%
pd.crosstab(df.Sex, df.Survived)
# Out:
# Survived    0    1
# Sex
# female     81  233
# male      468  109

# %%
pd.crosstab(df.Sex, df.Survived, normalize = "index")
# Out:
# Survived          0          1
# Sex
# female    25.796178  74.203822
# male      81.109185  18.890815

# %%
pd.crosstab(df.Sex, df.Survived, normalize = "columns")
# Out:
# Survived         0         1
# Sex
# female    0.147541  0.681287
# male      0.852459  0.318713

# %%
pd.crosstab(df.Sex,df.Survived, normalize = 'all')
# Out:
# Survived         0         1
# Sex
# female    0.090909  0.261504
# male      0.525253  0.122334

# %%
below_5_years = df[df.Age <= 5]

# %%
below_5_years[:5]
# Out:
#     PassengerId  Survived  Pclass                                      Name  \
# 7             8         0       3            Palsson, Master. Gosta Leonard
# 10           11         1       3           Sandstrom, Miss. Marguerite Rut
# 16           17         0       3                      Rice, Master. Eugene
# 43           44         1       2  Laroche, Miss. Simonne Marie Anne Andree
# 58           59         1       2              West, Miss. Constance Mirium
#
#        Sex  Age  SibSp  Parch         Ticket     Fare Cabin Embarked
# 7     male  2.0      3      1         349909  21.0750   NaN        S
# 10  female  4.0      1      1        PP 9549  16.7000    G6        S
# 16    male  2.0      4      1         382652  29.1250   NaN        Q
# 43  female  3.0      1      2  SC/Paris 2123  41.5792   NaN        C
# 58  female  5.0      1      2     C.A. 34651  27.7500   NaN        S

# %%
len(below_5_years)
# Out:
# 44

# %%
below_5_years['Survived'].value_counts()
# Out:
# 1    31
# 0    13
# Name: Survived, dtype: int64

# %%
below_5_years["Survived"].value_counts(normalize = 100)
# Out:
# 1    0.704545
# 0    0.295455
# Name: Survived, dtype: float64

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df[df.Name.str.contains("Allen")]
# Out:
#      PassengerId  Survived  Pclass                           Name     Sex  \
# 4              5         0       3       Allen, Mr. William Henry    male
# 730          731         1       1  Allen, Miss. Elisabeth Walton  female
#
#       Age  SibSp  Parch  Ticket      Fare Cabin Embarked
# 4    35.0      0      0  373450    8.0500   NaN        S
# 730  29.0      0      0   24160  211.3375    B5        S

# %%
df[df.Name.str.contains("Allen")]
# Out:
#      PassengerId  Survived  Pclass                           Name     Sex  \
# 4              5         0       3       Allen, Mr. William Henry    male
# 730          731         1       1  Allen, Miss. Elisabeth Walton  female
#
#       Age  SibSp  Parch  Ticket      Fare Cabin Embarked
# 4    35.0      0      0  373450    8.0500   NaN        S
# 730  29.0      0      0   24160  211.3375    B5        S

# %%
df.Embarked.value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
df.Embarked.value_counts(dropna=False)
# Out:
# S      644
# C      168
# Q       77
# NaN      2
# Name: Embarked, dtype: int64

# %%
df.Embarked.dropna().unique()
# Out:
# array(['S', 'C', 'Q'], dtype=object)

# %%
clean_df = df.dropna()

# %%
clean_df
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# 21            22         1       2
# 23            24         1       1
# 27            28         0       1
# 52            53         1       1
# 54            55         0       1
# 62            63         0       1
# 66            67         1       2
# 75            76         0       3
# 88            89         1       1
# 92            93         0       1
# 96            97         0       1
# 97            98         1       1
# 102          103         0       1
# 110          111         0       1
# 118          119         0       1
# 123          124         1       2
# 124          125         0       1
# 136          137         1       1
# 137          138         0       1
# 139          140         0       1
# ...

# %%
len(clean_df)
# Out:
# 183

# %%
clean_df = df.dropna(how = "all")

# %%
len(clean_df)
# Out:
# 891

# %%
clean_df[:6]
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# ...

# %%
clean_df = df.dropna(subset = ['Age','Pclass'], how ='any')

# %%
len(clean_df)
# Out:
# 714

# %%
clean_df = df.dropna(axis=1,how="any")

# %%
clean_df.shape
# Out:
# (891, 9)

# %%
clean_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 9 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# dtypes: float64(1), int64(5), object(3)
# memory usage: 62.7+ KB

# %%
df.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C

# %%
new_df = df.rename(columns = {'Age':'Years'},inplace=True)

# %%
df.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C

# %%
first_4 = df[:4]

# %%
first_4
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S

# %%
first_4_3 = df.iloc[:2,:5]

# %%
first_4_3
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex
# 0                            Braund, Mr. Owen Harris    male
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female

# %%
df[-1:]
# Out:
#      PassengerId  Survived  Pclass                 Name   Sex   Age  SibSp  \
# 890          891         0       3  Dooley, Mr. Patrick  male  32.0      0
#
#      Parch  Ticket  Fare Cabin Embarked
# 890      0  370376  7.75   NaN        Q

# %%
last_5=df[-5:]

# %%
last_5
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df[(df.Survived ==1) & (df.Age <=5)][['Age','Sex','Pclass']][:5]
# Out:
#       Age     Sex  Pclass
# 10   4.00  female       3
# 43   3.00  female       2
# 58   5.00  female       2
# 78   0.83    male       2
# 172  1.00  female       3

# %%
df[df.Age.isnull()][['Age','Survived','Sex','Pclass']][:5]
# Out:
#     Age  Survived     Sex  Pclass
# 5   NaN         0    male       3
# 17  NaN         1    male       2
# 19  NaN         1  female       3
# 26  NaN         0    male       3
# 28  NaN         1  female       3

# %%
df[-df.Age.isnull()][['Age','Pclass','Sex','Survived']][:5]
# Out:
#     Age  Pclass     Sex  Survived
# 0  22.0       3    male         0
# 1  38.0       1  female         1
# 2  26.0       3  female         1
# 3  35.0       1  female         1
# 4  35.0       3    male         0

# %%
df["Gender"] = df.Sex.map(lambda x: int (x=="male"))

# %%
df.head()
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0       3                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3  female  35.0      1      0            113803  53.1000  C123        S
# 4    male  35.0      0      0            373450   8.0500   NaN        S
#
#    Gender
# 0       1
# 1       0
# 2       0
# 3       0
# 4       1

# %%
df.drop("PassengerId", inplace = True, axis=1)

# %%
df.groupby('Pclass')['Age'].mean()
# Out:
# Pclass
# 1    38.233441
# 2    29.877630
# 3    25.140620
# Name: Age, dtype: float64

# %%
pclass_age_mean_df = df.groupby('Pclass')['Age'].mean().reset_index()

# %%
pclass_age_mean_df
# Out:
#    Pclass        Age
# 0       1  38.233441
# 1       2  29.877630
# 2       3  25.140620

# %%
pclass_gender_age_mean_df = df.groupby(['Pclass','Sex'])['Age'].mean().reset_index()

# %%
pclass_gender_age_mean_df
# Out:
#    Pclass     Sex        Age
# 0       1  female  34.611765
# 1       1    male  41.281386
# 2       2  female  28.722973
# 3       2    male  30.740707
# 4       3  female  21.750000
# 5       3    male  26.507589

# %%
pclass_gender_survived_count_df = df.groupby(['Pclass','Sex'])['Survived'].sum().reset_index()

# %%
pclass_gender_survived_count_df
# Out:
#    Pclass     Sex  Survived
# 0       1  female        91
# 1       1    male        45
# 2       2  female        70
# 3       2    male        17
# 4       3  female        72
# 5       3    male        47

# %%
pclass_age_gender_survived_df = pclass_gender_age_mean_df.merge(pclass_gender_survived_count_df, on = ['Pclass','Sex'])

# %%
pclass_age_gender_survived_df
# Out:
#    Pclass     Sex        Age  Survived
# 0       1  female  34.611765        91
# 1       1    male  41.281386        45
# 2       2  female  28.722973        70
# 3       2    male  30.740707        17
# 4       3  female  21.750000        72
# 5       3    male  26.507589        47

# %%
pclass_age_gender_survived_df.sort_values('Survived')
# Out:
#    Pclass     Sex        Age  Survived
# 3       2    male  30.740707        17
# 1       1    male  41.281386        45
# 5       3    male  26.507589        47
# 2       2  female  28.722973        70
# 4       3  female  21.750000        72
# 0       1  female  34.611765        91

# %%
pclass_age_gender_survived_df.sort_values('Survived', ascending = False)
# Out:
#    Pclass     Sex        Age  Survived
# 0       1  female  34.611765        91
# 4       3  female  21.750000        72
# 2       2  female  28.722973        70
# 5       3    male  26.507589        47
# 1       1    male  41.281386        45
# 3       2    male  30.740707        17
